# %% [markdown]
# ### Assignment Git & Github

# %% [markdown]
# ## Task 1
# ### Demonstrate minimum 15 basic Git command with explanation and screenshot.

# %% [markdown]
# 1. git diff filename :  This command helps us in getting the difference between an unstaged file with the last committed vesrion

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\Git\Git diff filename.jpg')

# %% [markdown]
# 2. git diff -r HEAD fielname: This command helps is finding the difference between a staged file and its previous committed version.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\Git\Git diff -r HEAD filename.jpg')

# %% [markdown]
# 3. git diff dfaeeb 538065: Git diff followed by first six characters of two specific commits separated by space displays the difference between the specific commits (can be obtained by git log command)

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\Git\git diff dfaeeb 538065.jpg')

# %% [markdown]
# 4. git show HEAD~1 : This command shows the changes in the second most commit

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\Git\git show HEAD~1.jpg')

# %% [markdown]
# 5.git annotate filename :  This command displays changes in author, particular changes, time of change, and commit hash for a specific file.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\Git\git annotate filename.jpg')

# %% [markdown]
# 6. git config --global alias.aliasname command : This helps in keeping any command in alias form for the quick execution.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\Git\git config --global alias.aliasname status.jpg')

# %% [markdown]
# 7. nano filename: Gives text editor output. We can make changes and save the file. (ctr + O, Enter, ctr + x)

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\nano.jpg')

# %% [markdown]
# 8. git reset HEAD filename : This command unstage an already staged file (by means of git add previously).

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\unstaging.jpg')

# %% [markdown]
# 9. git checkout -- filename: This command undo changes to unstaged file.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\undo.jpg')

# %% [markdown]
# 10. git reset hash : command unstages the file(s) to the previous commit hash (as provided in the commandline), editor can be used to make further chnages.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\git reset hash.jpg')

# %% [markdown]
# 11. git remote add remotename <github URL> : Commnd creates a new connection to a remote repository

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\new remote branch.jpg')

# %% [markdown]
# 12. git reset --hard HEAD ~ 1 : Changes after HEAD ~ 1 commit are destroyed. HEAD~1 is the second most recent commit.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\git reset --hard HEAD~1.jpg')

# %% [markdown]
# 13. git reflog : This command displays all changes of he local repositoyr's HEAD.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\git reflog.jpg')

# %% [markdown]
# 14. git rebase : This helps in avoiding merge conflict while pulling remote to local branch and generate a new feature branch followed by commits and pushing back to the remote. Rebase actually destroys all commits from the feature branch and copy those commits after the recent commit in the main branch. [Learning source: https://www.youtube.com/watch?v=BoXAv9M4boU]

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\git rebase.jpg')

# %% [markdown]
# 15. touch filenamewithextension : This command generates file in the local git repository e.g. c.js. Later, with the use of git add and git commit we can stage and commit the newly created file in local git repository.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\git\touch filename.jpg')

# %% [markdown]
# ## Task 2
# ### Consider that your want to start an open-source project in your organization. Perform all the standard operation to create a repository with minimal permision for all the users. It should contain.
# ### a) Proper open source structure
# ### b) Proper Readme
# ### c) Add 2 collaborator
# ### d) Host GitHub Pages using settings (Designed to host your personal, organization, or project pages from a GitHub repository)

# %% [markdown]
# https://github.com/Git-Learning-Study-LLC
